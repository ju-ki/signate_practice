# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os 
sns.set()
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv("dataset/dataset1.csv")
row = pd.read_csv("input/train.csv")

# %%
train.head()
# Out:
#    accommodates  amenities  bathrooms  bed_type  bedrooms  beds  \
# 0             6         84        2.0         4       1.0   4.0
# 1             2        350        1.0         4       1.0   1.0
# 2             2        447        2.0         4       1.0   1.0
# 3             2        224        1.0         4       1.0   1.0
# 4             2        226        1.0         4       1.0   1.0
#
#    cancellation_policy  city  cleaning_fee  description  ...   longitude  \
# 0                    0     3             1          304  ... -118.154761
# 1                    2     2             1          337  ...  -76.978190
# 2                    2     4             1          389  ...  -73.926240
# 3                    2     5             1          817  ... -122.411906
# 4                    2     4             1          828  ...  -73.974691
#
#    name  neighbourhood  number_of_reviews  property_type  \
# 0    12            394                  1              0
# ...

# %%
sns.barplot(x=train["cancellation_policy"], y=train["y"])

# %%
print(row["cancellation_policy"].value_counts())
sns.barplot(x=row["cancellation_policy"], y=row["y"])
plt.xticks(rotation=90)
plt.show()
# Out:
# strict             24318
# flexible           16886
# moderate           14288
# super_strict_30       78
# super_strict_60       13
# Name: cancellation_policy, dtype: int64

# %%
print(row["bed_type"].value_counts())
sns.barplot(x=row["bed_type"], y=row["y"])
plt.show()
# Out:
# Real Bed         53989
# Futon              569
# Pull-out Sofa      453
# Airbed             364
# Couch              208
# Name: bed_type, dtype: int64

# %%
print(row["cleaning_fee"].value_counts())
sns.barplot(x=row["cleaning_fee"], y=row["y"])
plt.show()
# Out:
# t    40821
# f    14762
# Name: cleaning_fee, dtype: int64

# %%
def plot_barplot_with_value_counts(data, column, target):
    print(data[column].value_counts())
    plt.figure(figsize=(16, 16))
    sns.barplot(x=data[column], y=data[target])
    plt.xticks(rotation=90)
    plt.show()

# %%
plot_barplot_with_value_counts(row, "city", "y")
# Out:
# NYC        24326
# LA         16828
# SF          4768
# DC          4259
# Chicago     2807
# Boston      2595
# Name: city, dtype: int64

# %%
plot_barplot_with_value_counts(row, "property_type", "y")
# Out:
# Apartment             36826
# House                 12326
# Condominium            1983
# Townhouse              1249
# Loft                    914
# Other                   448
# Guesthouse              392
# Bed & Breakfast         349
# Bungalow                281
# Villa                   131
# Dorm                    112
# Guest suite              96
# Camper/RV                71
# In-law                   60
# Timeshare                55
# Boat                     53
# Hostel                   51
# Boutique hotel           50
# Cabin                    47
# Serviced apartment       16
# Tent                     14
# Vacation home            11
# Castle                    9
# Yurt                      8
# Hut                       7
# Treehouse                 7
# Chalet                    4
# Earth House               4
# Tipi                      3
# Train                     2
# Casa particular           1
# Cave                      1
# Parking Space             1
# ...
